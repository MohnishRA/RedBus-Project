# %%
import pandas as pd

# %%
df = pd.read_csv(r"F:\Guvi\Projects\Uploading\bus_routes.csv")

# %%
"""    
Performs data type conversions and cleaning:
- Removes 'INR' from price
- Converts price to float
- Cleans seat availability text
- Converts seat availability to integer
- Converts star rating to float
"""

df['price'] = df['price'].str.replace('INR', '').astype(float)
df['seats_available'] = df['seats_available'].str.replace(' Seats available', '')
df['seats_available'] = df['seats_available'].str.replace(' Seat available', '')
df['seats_available'] = df['seats_available'].astype(int)
df['seats_available'] = df['seats_available'].fillna(0)
df['star_rating'] = df['star_rating'].astype(float)
df['star_rating'] = df['star_rating'].fillna(0)

# %%
df['bustype'].unique()
# Out:
# array(['SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)',
#        'AMARAVATHI (VOLVO / SCANIA A.C Multi Axle)', 'INDRA(A.C. Seater)',
#        'DOLPHIN CRUISE (VOLVO / SCANIA A.C Multi Axle)',
#        'NIGHT RIDER (SEATER CUM SLEEPER)',
#        'STAR LINER(NON-AC SLEEPER 2+1)', 'VENNELA (A.C. SLEEPER)',
#        'Super Luxury (Non AC Seater 2+2 Push Back)',
#        'Rajdhani (AC Semi Sleeper 2+2)', 'RAJDHANI (A.C. Semi Sleeper)',
#        'eGARUDA', 'GARUDA PLUS (VOLVO / BENZ A.C Multi Axle)',
#        'LAHARI A/C SLEEPER CUM SEATER',
#        'Lahari Non A/C Sleeper Cum Seater', 'Lahari A/C sleeper',
#        'Electric A/C Seater (2+2)',
#        'Bharat Benz A/C Seater /Sleeper (2+1)',
#        'Non A/C Seater / Sleeper (2+1)', 'A/C Seater / Sleeper (2+1)',
#        'AC Sleeper (2+1)', 'A/C Sleeper (2+1)',
#        'Scania AC Multi Axle Sleeper (2+1)',
#        'Electric A/C Seater/Sleeper (2+1)',
#        'NON A/C Seater/ Sleeper (2+1)', 'VE A/C Sleeper (2+1)',
# ...

# %%
df['bustype'] = df['bustype'].replace('SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)', 'Non-AC Semi-Sleeper')
df['bustype'] = df['bustype'].replace('AMARAVATHI (VOLVO / SCANIA A.C Multi Axle)','AC Semi-Sleeper')
df['bustype'] = df['bustype'].replace('INDRA(A.C. Seater)', 'AC Seater')
df['bustype'] = df['bustype'].replace('DOLPHIN CRUISE (VOLVO / SCANIA A.C Multi Axle)', 'AC Semi-Sleeper')
df['bustype'] = df['bustype'].replace('NIGHT RIDER (SEATER CUM SLEEPER)', 'Non-AC Seater/Sleeper')
df['bustype'] = df['bustype'].replace('STAR LINER(NON-AC SLEEPER 2+1)', 'Non-AC Sleeper')
df['bustype'] = df['bustype'].replace('VENNELA (A.C. SLEEPER)', 'AC Sleeper')
df['bustype'] = df['bustype'].replace('Super Luxury (Non AC Seater 2+2 Push Back)', 'Non-AC Semi-Sleeper')
df['bustype'] = df['bustype'].replace('Rajdhani (AC Semi Sleeper 2+2)', 'AC Semi-Sleeper')
df['bustype'] = df['bustype'].replace('RAJDHANI (A.C. Semi Sleeper)', 'AC Semi-Sleeper')
df['bustype'] = df['bustype'].replace('eGARUDA', 'AC Semi-Sleeper')
df['bustype'] = df['bustype'].replace('GARUDA PLUS (VOLVO / BENZ A.C Multi Axle)', 'AC Semi-Sleeper')
df['bustype'] = df['bustype'].replace('LAHARI A/C SLEEPER CUM SEATER', 'AC Seater/Sleeper')
df['bustype'] = df['bustype'].replace('Lahari Non A/C Sleeper Cum Seater', 'AC Seater/Sleeper')
df['bustype'] = df['bustype'].replace('Lahari A/C sleeper', 'AC Sleeper')
df['bustype'] = df['bustype'].replace('Electric A/C Seater (2+2)', 'AC Seater')
df['bustype'] = df['bustype'].replace('Bharat Benz A/C Seater /Sleeper (2+1)', 'AC Seater/Sleeper')
df['bustype'] = df['bustype'].replace('Non A/C Seater / Sleeper (2+1)', 'AC Seater/Sleeper')
df['bustype'] = df['bustype'].replace('A/C Seater / Sleeper (2+1)', 'AC Seater/Sleeper')
df['bustype'] = df['bustype'].replace('AC Sleeper (2+1)', 'AC Sleeper')
df['bustype'] = df['bustype'].replace('A/C Sleeper (2+1)', 'AC Sleeper')
df['bustype'] = df['bustype'].replace('Scania AC Multi Axle Sleeper (2+1)', 'AC Sleeper')
df['bustype'] = df['bustype'].replace('Electric A/C Seater/Sleeper (2+1)', 'AC Seater/Sleeper')
df['bustype'] = df['bustype'].replace('NON A/C Seater/ Sleeper (2+1)', 'AC Seater/Sleeper')
df['bustype'] = df['bustype'].replace('VE A/C Sleeper (2+1)', 'AC Sleeper')
df['bustype'] = df['bustype'].replace('Bharat Benz A/C Sleeper (2+1)', 'AC Sleeper')
df['bustype'] = df['bustype'].replace('Volvo Multi Axle A/C Sleeper I-Shift B11R (2+1)', 'AC Sleeper')
df['bustype'] = df['bustype'].replace('VE A/C Seater / Sleeper (2+1)', 'AC Seater/Sleeper')
df['bustype'] = df['bustype'].replace('NON A/C Sleeper (2+1)', 'Non-AC Sleeper')
df['bustype'] = df['bustype'].replace('NON AC Seater / Sleeper 2+1', 'Non-AC Seater/Sleeper')
df['bustype'] = df['bustype'].replace('A/C Seater (2+2)', 'AC Seater')
df['bustype'] = df['bustype'].replace('A/C Volvo B11R Multi-Axle Sleeper (2+1)', 'AC Sleeper')
df['bustype'] = df['bustype'].replace('NON A/C Push Back (2+2)', 'Non-AC Semi-Sleeper')
df['bustype'] = df['bustype'].replace('A/C Seater/Sleeper (2+1)', 'AC Seater/Sleeper')
df['bustype'] = df['bustype'].replace('Volvo Multi-Axle A/C Sleeper (2+1)', 'AC Sleeper')
df['bustype'] = df['bustype'].replace('Volvo 9600 A/C Seater/Sleeper (2+1)', 'AC Seater/Sleeper')
df['bustype'] = df['bustype'].replace('Volvo 9600 Multi-Axle A/C Sleeper (2+1)', 'AC Sleeper')
df['bustype'] = df['bustype'].replace('Scania Multi-Axle AC Seater (2+2)', 'AC Seater')
df['bustype'] = df['bustype'].replace('Volvo Multi Axle B9R A/C Sleeper (2+1)', 'AC Sleeper')
df['bustype'] = df['bustype'].replace('NON A/C Semi Sleeper (2+1)', 'AC Semi-Sleeper')
df['bustype'] = df['bustype'].replace('NON A/C Semi Sleeper / Sleeper (2+1)', 'Non-AC Seater/Sleeper')
df['bustype'] = df['bustype'].replace('2+1 Air Suspension A/C Seater / Sleeper', 'AC Seater/Sleeper')
df['bustype'] = df['bustype'].replace('Volvo Multi-Axle B9R A/c Semi Sleeper (2+2)', 'AC Semi-Sleeper')
df['bustype'] = df['bustype'].replace('AC Seater (2+2)', 'AC Seater')
df['bustype'] = df['bustype'].replace('Volvo Multi-Axle A/C (2+1)', 'AC Sleeper')
df['bustype'] = df['bustype'].replace('Volvo A/C Semi Sleeper (2+2)', 'AC Semi-Sleeper')
df['bustype'] = df['bustype'].replace('NON A/C Hi-Tech (2+2)', 'Non-AC Semi-Sleeper')
df['bustype'] = df['bustype'].replace('METRO LUXURY A/C', 'AC Sleeper')
df['bustype'] = df['bustype'].replace('Express(Non AC Seater)', 'Non-AC Seater')
df['bustype'] = df['bustype'].replace('Non AC Seater (2+3)', 'Non-AC Seater')
df['bustype'] = df['bustype'].replace('A/C Semi Sleeper / Sleeper (2+1)', 'AC Seater/Sleeper')
df['bustype'] = df['bustype'].replace('Non AC Seater (2+2)', 'Non-AC Seater')
df['bustype'] = df['bustype'].replace('NON A/C Hi-Tech Push Back (2+2)', 'Non-AC Semi-Sleeper')
df['bustype'] = df['bustype'].replace('Volvo Multi-Axle Sleeper A/C (2+1)', 'AC Sleeper')
df['bustype'] = df['bustype'].replace('SAPTAGIRI EXPRESS', 'Non-AC Seater')
df['bustype'] = df['bustype'].replace('VE Executive A/C Sleeper (1+1)', 'AC Sleeper')
df['bustype'] = df['bustype'].replace('Volvo Multi-Axle A/C Semisleeper (2+2)', 'AC Semi-Sleeper')
df['bustype'] = df['bustype'].replace('Volvo Multi-Axle A/C Semi Sleeper (2+2)', 'AC Semi-Sleeper')
df['bustype'] = df['bustype'].replace('NON A/C Seater (2+3)', 'Non-AC Seater')
df['bustype'] = df['bustype'].replace('Volvo Multi-Axle I-Shift A/C Semi Sleeper (2+2)', 'AC Semi-Sleeper')
df['bustype'] = df['bustype'].replace('Scania Multi-Axle AC Semi Sleeper (2+2)', 'AC Semi-Sleeper')
df['bustype'] = df['bustype'].replace('Volvo A/C B11R Multi Axle Semi Sleeper (2+2)', 'AC Semi-Sleeper')
df['bustype'] = df['bustype'].replace('NON A/C Seater (2+2)', 'Non-AC Seater')
df['bustype'] = df['bustype'].replace('Volvo Multi-Axle I-Shift B11R Semi Sleeper (2+2)', 'AC Semi-Sleeper')
df['bustype'] = df['bustype'].replace('NON A/C Seater PushBack (2+2)', 'Non-AC Semi-Sleeper')
df['bustype'] = df['bustype'].replace('A/C Seater Push Back (2+2)', 'AC Semi-Sleeper')
df['bustype'] = df['bustype'].replace('Bharat Benz A/C Sleeper (1+1)', 'AC Sleeper')
df['bustype'] = df['bustype'].replace('Benz A/C Sleeper (2+1)', 'AC Sleeper')
df['bustype'] = df['bustype'].replace('RAJADHANI AC (CONVERTED METRO LUXURY)', 'AC Sleeper')
df['bustype'] = df['bustype'].replace('NON A/C Executive (2+1)', 'Non-AC Sleeper')
df['bustype'] = df['bustype'].replace('Mercedes Benz A/C Sleeper (2+1)', 'AC Sleeper')
df['bustype'] = df['bustype'].replace('Deluxe (Non AC Seater 2+2)', 'Non-AC Seater')
df['bustype'] = df['bustype'].replace('NON A/C Seater / Sleeper (2+2)', 'Non-AC Seater/Sleeper')
df['bustype'] = df['bustype'].replace('e-SUP LUXURY (2+2)', 'AC Semi-Sleeper')
df['bustype'] = df['bustype'].replace('NON A/C Sleeper (2+2)', 'Non-AC Sleeper')
df['bustype'] = df['bustype'].replace('Bharat Benz A/C Seater (2+2)', 'AC Seater')
df['bustype'] = df['bustype'].replace('Volvo Multi Axle Sleeper B11R (2+1)', 'AC Sleeper')
df['bustype'] = df['bustype'].replace('NON A/C Seater (2+1)', 'Non-AC Seater')
df['bustype'] = df['bustype'].replace('VE Non A/C Sleeper (2+1)', 'Non-AC Sleeper')
df['bustype'] = df['bustype'].replace('NON A/C Seater Push Back (2+2)', 'Non-AC Semi-Sleeper')
df['bustype'] = df['bustype'].replace('Super Fast Non AC Seater (2+3)', 'Non-AC Seater')
df['bustype'] = df['bustype'].replace('Low Floor AC Seater 2+2', 'AC Seater')
df['bustype'] = df['bustype'].replace('Super Express Non AC Seater Air Bus (2+2)', 'Non-AC Seater')
df['bustype'] = df['bustype'].replace('Swift Deluxe Non AC Air Bus (2+2)', 'Non-AC Semi-Sleeper')
df['bustype'] = df['bustype'].replace('AC MULTI AXLE', 'AC Sleeper')
df['bustype'] = df['bustype'].replace('NON A/C Semi Sleeper (2+2)', 'Non-AC Semi-Sleeper')
df['bustype'] = df['bustype'].replace('A/C Semi Sleeper (2+2)', 'AC Semi-Sleeper')
df['bustype'] = df['bustype'].replace('Bharat Benz A/C Semi Sleeper (2+2)', 'AC Semi-Sleeper')
df['bustype'] = df['bustype'].replace('SWIFT-GARUDA A/C SEATER BUS', 'AC Seater')
df['bustype'] = df['bustype'].replace('Bharat Benz (2+2)', 'AC Semi-Sleeper')
df['bustype'] = df['bustype'].replace('SWIFT-HYBRID NON AC SEATER CUM SLEEPER', 'Non-AC Seater/Sleeper')
df['bustype'] = df['bustype'].replace('Super Deluxe Non AC Seater Air Bus (2+2)', 'Non-AC Seater')
df['bustype'] = df['bustype'].replace('Volvo AC Seater (2+2)', 'AC Seater')
df['bustype'] = df['bustype'].replace('Volvo A/C Seater (2+2)', 'AC Seater')
df['bustype'] = df['bustype'].replace('Volvo 9600 A/C Semi Sleeper (2+2)', 'AC Semi-Sleeper')
df['bustype'] = df['bustype'].replace('Volvo B11R Multi Axle Seater (2+2)', 'AC Seater')
df['bustype'] = df['bustype'].replace('Volvo 9600 A/C Seater (2+2)', 'AC Seater')
df['bustype'] = df['bustype'].replace('A/C Seater (2+3)', 'AC Seater')
df['bustype'] = df['bustype'].replace('Volvo 9600 Multi Axle Semi-Sleeper (2+2)', 'AC Semi-Sleeper')
df['bustype'] = df['bustype'].replace('Volvo A/C Seater / Sleeper (2+1)', 'AC Seater/Sleeper')
df['bustype'] = df['bustype'].replace('A/C Seater / Sleeper (2+2)', 'AC Seater/Sleeper')
df['bustype'] = df['bustype'].replace('Volvo Multi-Axle A/C Seater/Sleeper (2+1)', 'AC Seater/Sleeper')
df['bustype'] = df['bustype'].replace('AC Seater (2+3)', 'AC Seater')
df['bustype'] = df['bustype'].replace('A/C Executive (2+3)', 'AC Seater')
df['bustype'] = df['bustype'].replace('Express Non AC Seater 2+3', 'Non-AC Seater')
df['bustype'] = df['bustype'].replace('VE A/C Seater (2+2)', 'AC Seater')
df['bustype'] = df['bustype'].replace('A/C Seater Push Back (2+3)', 'AC Semi-Sleeper')
df['bustype'] = df['bustype'].replace('A/C Push Back (2+3)', 'AC Semi-Sleeper')
df['bustype'] = df['bustype'].replace('Express (Non AC Seater 2+2)', 'Non-AC Seater')
df['bustype'] = df['bustype'].replace('NON A/C Seater Push Back (2+3) (2+3)', 'Non-AC Seater')
df['bustype'] = df['bustype'].replace('Volvo AC Seater 2+2', 'AC Seater')
df['bustype'] = df['bustype'].replace('A/C Seater Hi-Tech Push Back (2+2)', 'AC Semi-Sleeper')
df['bustype'] = df['bustype'].replace('Tata A/C Seater (2+2)', 'AC Seater')
df['bustype'] = df['bustype'].replace('Leyland A/C Seater Executive (2+2)', 'AC Seater')
df['bustype'] = df['bustype'].replace('Ordinary 3+2 Non AC Seater', 'Non-AC Seater')
df['bustype'] = df['bustype'].replace('Himsuta AC Seater Volvo/Scania 2+2', 'AC Seater')
df['bustype'] = df['bustype'].replace('Mercedes Multi-Axle Semi Sleeper (2+2)', 'AC Semi-Sleeper')
df['bustype'] = df['bustype'].replace('Scania A/C Semi Sleeper (2+2)', 'AC Semi-Sleeper')
df['bustype'] = df['bustype'].replace('Super Luxury Volvo AC Seater Pushback 2+2', 'AC Seater')
df['bustype'] = df['bustype'].replace('HVAC Seater (2+3)', 'AC Seater')
df['bustype'] = df['bustype'].replace('Volvo A/C Sleeper (2+2)', 'AC Sleeper')
df['bustype'] = df['bustype'].replace('Bharat Benz NON A/C Seater / Sleeper (2+1)', 'AC Seater/Sleeper')
df['bustype'] = df['bustype'].replace('Volvo A/C (2+2)', 'AC Semi-Sleeper')
df['bustype'] = df['bustype'].replace('A/C Sleeper (2+2)', 'AC Sleeper')
df['bustype'] = df['bustype'].replace('Bharat Benz A/C Seater / Sleeper (2+2)', 'AC Seater/Sleeper')
df['bustype'] = df['bustype'].replace('Volvo A/C Sleeper (2+1)', 'AC Sleeper')
df['bustype'] = df['bustype'].replace('Mercedes A/C Semi Sleeper (2+2)', 'AC Semi-Sleeper')
df['bustype'] = df['bustype'].replace('Volvo A/C Multi-Axle Semi Sleeper (2+2)', 'AC Semi-Sleeper')
df['bustype'] = df['bustype'].replace('VE A/C Sleeper (2+2)', 'AC Sleeper')
df['bustype'] = df['bustype'].replace('Volvo A/C Semi Sleeper (2+2 )', 'AC Semi-Sleeper')
df['bustype'] = df['bustype'].replace('Himmani Deluxe 2+2 Non AC Seater', 'Non-AC Seater')
df['bustype'] = df['bustype'].replace('VE A/C Semi Sleeper (2+2)', 'AC Semi-Sleeper')
df['bustype'] = df['bustype'].replace('Volvo Multi Axle B11R AC Seater\\Sleeper (2+1)', 'AC Seater/Sleeper')
df['bustype'] = df['bustype'].replace('A/C Semi Sleeper / Sleeper (2+2)', 'AC Seater/Sleeper')
df['bustype'] = df['bustype'].replace('VE A/C Seater / Sleeper (2+2)', 'AC Seater/Sleeper')
df['bustype'] = df['bustype'].replace('AC Seater Hvac 2+2', 'AC Seater')
df['bustype'] = df['bustype'].replace('NON A/C (2+1)', 'Non-AC Sleeper')
df['bustype'] = df['bustype'].replace('Bharat Benz A/C Seater (2+1)', 'AC Seater')
df['bustype'] = df['bustype'].replace('Volvo AC Seater Pushback 2+2', 'AC Semi-Sleeper')
df['bustype'] = df['bustype'].replace('NON A/C Seater Semi Sleeper (2+1)', 'AC Seater/Sleeper')
df['bustype'] = df['bustype'].replace('NON AC Seater/ Sleeper (2+1)', 'AC Seater/Sleeper')
df['bustype'] = df['bustype'].replace('A/C Seater (2+1)', 'AC Seater')
df['bustype'] = df['bustype'].replace('Non AC Seater (2+1)', 'Non-AC Seater')
df['bustype'] = df['bustype'].replace('Tempo Traveler NON A/C', 'Non-AC Seater')
df['bustype'] = df['bustype'].replace('A/C Seater Push Back (2+1)', 'AC Semi-Sleeper')
df['bustype'] = df['bustype'].replace('NON A/C Seater Push Back (2+1)', 'Non-AC Semi-Sleeper')
df['bustype'] = df['bustype'].replace('ULTRA DELUXE (NON-AC, 2+2 PUSH BACK)', 'Non-AC Semi-Sleeper')

# %%
df['bustype'].unique()
# Out:
# array(['Non-AC Semi-Sleeper', 'AC Semi-Sleeper', 'AC Seater',
#        'Non-AC Seater/Sleeper', 'Non-AC Sleeper', 'AC Sleeper',
#        'AC Seater/Sleeper', 'Non-AC Seater'], dtype=object)

# %%
df.to_csv('corrected_bus_types.csv', index=False)
